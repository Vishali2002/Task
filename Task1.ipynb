# %% [markdown]
# # ASSIGNMENT 5
# # CSE4076 - Image and Video Analytics
# BY:
#
# VISHALI SHARMA (21MIA1066)

# %% [markdown]
# Load Video:

# %%
import cv2
import os

# Load the video
video_path = '33871-398473585_small.mp4'
cap = cv2.VideoCapture(video_path)

# Directory to save grayscale frames
output_dir = 'frames'
os.makedirs(output_dir, exist_ok=True)

# Frame counter
frame_num = 0

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Convert frame to grayscale
    gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    
    # Save the grayscale frame
    frame_filename = os.path.join(output_dir, f'frame_{frame_num}.png')
    cv2.imwrite(frame_filename, gray_frame)
    
    frame_num += 1

cap.release()
cv2.destroyAllWindows()

print(f"Total {frame_num} frames extracted and saved in {output_dir}")
# Out:
# Total 628 frames extracted and saved in frames

# %% [markdown]
# # Motion Estimation:

# %%
import os
import cv2
import numpy as np

# Directory where grayscale frames are saved
frame_dir = 'frames'

# Get the list of frame filenames
frame_files = sorted([f for f in os.listdir(frame_dir) if f.endswith('.png')], key=lambda x: int(x.split('_')[1].split('.')[0]))

# Threshold for motion detection (tune this value based on experimentation)
motion_threshold = 30  # For pixel differences
highlight_dir = 'highlighted_motion_frames'
os.makedirs(highlight_dir, exist_ok=True)

# File to save the motion estimation values
motion_estimation_file = 'motion_estimation.txt'

# Initialize variables
previous_frame = None
motion_estimations = []

for frame_file in frame_files:
    # Load the grayscale frame
    frame_path = os.path.join(frame_dir, frame_file)
    gray_frame = cv2.imread(frame_path, cv2.IMREAD_GRAYSCALE)
    
    if previous_frame is None:
        previous_frame = gray_frame
        continue
    
    # Compute absolute difference between the current frame and the previous frame
    diff_frame = cv2.absdiff(previous_frame, gray_frame)
    
    # Threshold the difference to highlight moving regions
    _, thresh_frame = cv2.threshold(diff_frame, motion_threshold, 255, cv2.THRESH_BINARY)
    
    # Calculate the motion estimation as the sum of the pixel differences
    motion_value = np.sum(thresh_frame)
    motion_estimations.append(motion_value)
    
    # Convert the grayscale frame to color so we can highlight moving regions
    color_frame = cv2.cvtColor(gray_frame, cv2.COLOR_GRAY2BGR)
    
    # Highlight moving regions in red
    color_frame[thresh_frame > 0] = [0, 0, 255]
    
    # Save the highlighted frame
    highlighted_frame_path = os.path.join(highlight_dir, frame_file)
    cv2.imwrite(highlighted_frame_path, color_frame)
    
    # Update the previous frame for the next iteration
    previous_frame = gray_frame

# Save the motion estimations to a file
np.savetxt(motion_estimation_file, motion_estimations, fmt='%d')

print(f"Highlighted motion frames saved in {highlight_dir}")
print(f"Motion estimation values saved in {motion_estimation_file}")
# Out:
# Highlighted motion frames saved in highlighted_motion_frames
# Motion estimation values saved in motion_estimation.txt

# %% [markdown]
# # Event Detection:

# %%
import os
import cv2
import numpy as np

# Load motion estimation values
motion_estimation = np.loadtxt('motion_estimation.txt')

# Directory where original frames are saved
frame_dir = 'frames'

# Get the list of frame filenames
frame_files = sorted([f for f in os.listdir(frame_dir) if f.endswith('.png')], key=lambda x: int(x.split('_')[1].split('.')[0]))

# Event threshold (adjust based on experimentation)
event_threshold = 50000

# Directory to save event-annotated frames
event_dir = 'annotated_event_frames'
os.makedirs(event_dir, exist_ok=True)

event_count = 0
timestamps = []

# FPS (adjust based on your video)
fps = 30  # Example FPS value

# Adjust the loop to avoid out-of-range errors
for i, motion_value in enumerate(motion_estimation[:-1]):  # Stop at the second-to-last motion value
    if motion_value > event_threshold:
        event_count += 1
        
        # Load the frame where the event occurs
        frame_path = os.path.join(frame_dir, frame_files[i+1])  # +1 because motion is calculated for the next frame
        frame = cv2.imread(frame_path)
        
        if frame is not None:
            # Optionally annotate the frame here
            annotated_frame_path = os.path.join(event_dir, f'event_frame_{event_count}.png')
            cv2.imwrite(annotated_frame_path, frame)
            
            # Store the timestamp (frame index / fps gives the time in seconds)
            timestamp = (i+1) / fps
            timestamps.append(timestamp)

# Optionally, save the timestamps of events to a file
np.savetxt('event_timestamps.txt', timestamps)

# %% [markdown]
# # Result:

# %%
# Directory where grayscale frames are saved
import matplotlib.pyplot as plt

frame_dir = 'frames'

# Get the list of frame filenames
frame_files = sorted([f for f in os.listdir(frame_dir) if f.endswith('.png')], key=lambda x: int(x.split('_')[1].split('.')[0]))

# Create a directory to save the histograms
histogram_dir = 'histograms'
os.makedirs(histogram_dir, exist_ok=True)

for frame_file in frame_files:
    # Load the grayscale frame
    gray_frame = cv2.imread(os.path.join(frame_dir, frame_file), cv2.IMREAD_GRAYSCALE)

    # Calculate histogram
    hist = cv2.calcHist([gray_frame], [0], None, [256], [0, 256])

    # Plot and save the histogram
    plt.figure()
    plt.title(f"Histogram for {frame_file}")
    plt.xlabel("Pixel Value")
    plt.ylabel("Frequency")
    plt.plot(hist)
    
    hist_file = os.path.join(histogram_dir, f'hist_{frame_file}.png')
    plt.savefig(hist_file)
    plt.close()

    print(f"Histogram saved for {frame_file}")
# Out:
# Histogram saved for frame_0.png
# Histogram saved for frame_1.png
# Histogram saved for frame_2.png
# Histogram saved for frame_3.png
# Histogram saved for frame_4.png
# Histogram saved for frame_5.png
# Histogram saved for frame_6.png
# Histogram saved for frame_7.png
# Histogram saved for frame_8.png
# Histogram saved for frame_9.png
# Histogram saved for frame_10.png
# Histogram saved for frame_11.png
# Histogram saved for frame_12.png
# Histogram saved for frame_13.png
# Histogram saved for frame_14.png
# Histogram saved for frame_15.png
# Histogram saved for frame_16.png
# Histogram saved for frame_17.png
# Histogram saved for frame_18.png
# Histogram saved for frame_19.png
# Histogram saved for frame_20.png
# Histogram saved for frame_21.png
# Histogram saved for frame_22.png
# Histogram saved for frame_23.png
# Histogram saved for frame_24.png
# Histogram saved for frame_25.png
# Histogram saved for frame_26.png
# Histogram saved for frame_27.png
# Histogram saved for frame_28.png
# Histogram saved for frame_29.png
# Histogram saved for frame_30.png
# Histogram saved for frame_31.png
# Histogram saved for frame_32.png
# Histogram saved for frame_33.png
# Histogram saved for frame_34.png
# Histogram saved for frame_35.png
# Histogram saved for frame_36.png
# Histogram saved for frame_37.png
# Histogram saved for frame_38.png
# Histogram saved for frame_39.png
# Histogram saved for frame_40.png
# Histogram saved for frame_41.png
# Histogram saved for frame_42.png
# Histogram saved for frame_43.png
# Histogram saved for frame_44.png
# Histogram saved for frame_45.png
# Histogram saved for frame_46.png
# Histogram saved for frame_47.png
# Histogram saved for frame_48.png
# Histogram saved for frame_49.png
# Histogram saved for frame_50.png
# Histogram saved for frame_51.png
# Histogram saved for frame_52.png
# Histogram saved for frame_53.png
# Histogram saved for frame_54.png
# Histogram saved for frame_55.png
# Histogram saved for frame_56.png
# Histogram saved for frame_57.png
# Histogram saved for frame_58.png
# Histogram saved for frame_59.png
# Histogram saved for frame_60.png
# Histogram saved for frame_61.png
# Histogram saved for frame_62.png
# Histogram saved for frame_63.png
# Histogram saved for frame_64.png
# Histogram saved for frame_65.png
# Histogram saved for frame_66.png
# Histogram saved for frame_67.png
# Histogram saved for frame_68.png
# Histogram saved for frame_69.png
# Histogram saved for frame_70.png
# Histogram saved for frame_71.png
# Histogram saved for frame_72.png
# Histogram saved for frame_73.png
# Histogram saved for frame_74.png
# Histogram saved for frame_75.png
# Histogram saved for frame_76.png
# Histogram saved for frame_77.png
# Histogram saved for frame_78.png
# Histogram saved for frame_79.png
# Histogram saved for frame_80.png
# Histogram saved for frame_81.png
# Histogram saved for frame_82.png
# Histogram saved for frame_83.png
# Histogram saved for frame_84.png
# Histogram saved for frame_85.png
# Histogram saved for frame_86.png
# Histogram saved for frame_87.png
# Histogram saved for frame_88.png
# Histogram saved for frame_89.png
# Histogram saved for frame_90.png
# Histogram saved for frame_91.png
# Histogram saved for frame_92.png
# Histogram saved for frame_93.png
# Histogram saved for frame_94.png
# Histogram saved for frame_95.png
# Histogram saved for frame_96.png
# Histogram saved for frame_97.png
# Histogram saved for frame_98.png
# Histogram saved for frame_99.png
# Histogram saved for frame_100.png
# Histogram saved for frame_101.png
# Histogram saved for frame_102.png
# Histogram saved for frame_103.png
# Histogram saved for frame_104.png
# Histogram saved for frame_105.png
# Histogram saved for frame_106.png
# Histogram saved for frame_107.png
# Histogram saved for frame_108.png
# Histogram saved for frame_109.png
# Histogram saved for frame_110.png
# Histogram saved for frame_111.png
# Histogram saved for frame_112.png
# Histogram saved for frame_113.png
# Histogram saved for frame_114.png
# Histogram saved for frame_115.png
# Histogram saved for frame_116.png
# Histogram saved for frame_117.png
# Histogram saved for frame_118.png
# Histogram saved for frame_119.png
# Histogram saved for frame_120.png
# Histogram saved for frame_121.png
# Histogram saved for frame_122.png
# Histogram saved for frame_123.png
# Histogram saved for frame_124.png
# Histogram saved for frame_125.png
# Histogram saved for frame_126.png
# Histogram saved for frame_127.png
# Histogram saved for frame_128.png
# Histogram saved for frame_129.png
# Histogram saved for frame_130.png
# Histogram saved for frame_131.png
# Histogram saved for frame_132.png
# Histogram saved for frame_133.png
# Histogram saved for frame_134.png
# Histogram saved for frame_135.png
# Histogram saved for frame_136.png
# Histogram saved for frame_137.png
# Histogram saved for frame_138.png
# Histogram saved for frame_139.png
# Histogram saved for frame_140.png
# Histogram saved for frame_141.png
# Histogram saved for frame_142.png
# Histogram saved for frame_143.png
# Histogram saved for frame_144.png
# Histogram saved for frame_145.png
# Histogram saved for frame_146.png
# Histogram saved for frame_147.png
# Histogram saved for frame_148.png
# Histogram saved for frame_149.png
# Histogram saved for frame_150.png
# Histogram saved for frame_151.png
# Histogram saved for frame_152.png
# Histogram saved for frame_153.png
# Histogram saved for frame_154.png
# Histogram saved for frame_155.png
# Histogram saved for frame_156.png
# Histogram saved for frame_157.png
# Histogram saved for frame_158.png
# Histogram saved for frame_159.png
# Histogram saved for frame_160.png
# Histogram saved for frame_161.png
# Histogram saved for frame_162.png
# Histogram saved for frame_163.png
# Histogram saved for frame_164.png
# Histogram saved for frame_165.png
# Histogram saved for frame_166.png
# Histogram saved for frame_167.png
# Histogram saved for frame_168.png
# Histogram saved for frame_169.png
# Histogram saved for frame_170.png
# Histogram saved for frame_171.png
# Histogram saved for frame_172.png
# Histogram saved for frame_173.png
# Histogram saved for frame_174.png
# Histogram saved for frame_175.png
# Histogram saved for frame_176.png
# Histogram saved for frame_177.png
# Histogram saved for frame_178.png
# Histogram saved for frame_179.png
# Histogram saved for frame_180.png
# Histogram saved for frame_181.png
# Histogram saved for frame_182.png
# Histogram saved for frame_183.png
# Histogram saved for frame_184.png
# Histogram saved for frame_185.png
# Histogram saved for frame_186.png
# Histogram saved for frame_187.png
# Histogram saved for frame_188.png
# Histogram saved for frame_189.png
# Histogram saved for frame_190.png
# Histogram saved for frame_191.png
# Histogram saved for frame_192.png
# Histogram saved for frame_193.png
# Histogram saved for frame_194.png
# Histogram saved for frame_195.png
# Histogram saved for frame_196.png
# Histogram saved for frame_197.png
# Histogram saved for frame_198.png
# Histogram saved for frame_199.png
# Histogram saved for frame_200.png
# Histogram saved for frame_201.png
# Histogram saved for frame_202.png
# Histogram saved for frame_203.png
# Histogram saved for frame_204.png
# Histogram saved for frame_205.png
# Histogram saved for frame_206.png
# Histogram saved for frame_207.png
# Histogram saved for frame_208.png
# Histogram saved for frame_209.png
# Histogram saved for frame_210.png
# Histogram saved for frame_211.png
# Histogram saved for frame_212.png
# Histogram saved for frame_213.png
# Histogram saved for frame_214.png
# Histogram saved for frame_215.png
# Histogram saved for frame_216.png
# Histogram saved for frame_217.png
# Histogram saved for frame_218.png
# Histogram saved for frame_219.png
# Histogram saved for frame_220.png
# Histogram saved for frame_221.png
# Histogram saved for frame_222.png
# Histogram saved for frame_223.png
# Histogram saved for frame_224.png
# Histogram saved for frame_225.png
# Histogram saved for frame_226.png
# Histogram saved for frame_227.png
# Histogram saved for frame_228.png
# Histogram saved for frame_229.png
# Histogram saved for frame_230.png
# Histogram saved for frame_231.png
# Histogram saved for frame_232.png
# Histogram saved for frame_233.png
# Histogram saved for frame_234.png
# Histogram saved for frame_235.png
# Histogram saved for frame_236.png
# Histogram saved for frame_237.png
# Histogram saved for frame_238.png
# Histogram saved for frame_239.png
# Histogram saved for frame_240.png
# Histogram saved for frame_241.png
# Histogram saved for frame_242.png
# Histogram saved for frame_243.png
# Histogram saved for frame_244.png
# Histogram saved for frame_245.png
# Histogram saved for frame_246.png
# Histogram saved for frame_247.png
# Histogram saved for frame_248.png
# Histogram saved for frame_249.png
# Histogram saved for frame_250.png
# Histogram saved for frame_251.png
# Histogram saved for frame_252.png
# Histogram saved for frame_253.png
# Histogram saved for frame_254.png
# Histogram saved for frame_255.png
# Histogram saved for frame_256.png
# Histogram saved for frame_257.png
# Histogram saved for frame_258.png
# Histogram saved for frame_259.png
# Histogram saved for frame_260.png
# Histogram saved for frame_261.png
# Histogram saved for frame_262.png
# Histogram saved for frame_263.png
# Histogram saved for frame_264.png
# Histogram saved for frame_265.png
# Histogram saved for frame_266.png
# Histogram saved for frame_267.png
# Histogram saved for frame_268.png
# Histogram saved for frame_269.png
# Histogram saved for frame_270.png
# Histogram saved for frame_271.png
# Histogram saved for frame_272.png
# Histogram saved for frame_273.png
# Histogram saved for frame_274.png
# Histogram saved for frame_275.png
# Histogram saved for frame_276.png
# Histogram saved for frame_277.png
# Histogram saved for frame_278.png
# Histogram saved for frame_279.png
# Histogram saved for frame_280.png
# Histogram saved for frame_281.png
# Histogram saved for frame_282.png
# Histogram saved for frame_283.png
# Histogram saved for frame_284.png
# Histogram saved for frame_285.png
# Histogram saved for frame_286.png
# Histogram saved for frame_287.png
# Histogram saved for frame_288.png
# Histogram saved for frame_289.png
# Histogram saved for frame_290.png
# Histogram saved for frame_291.png
# Histogram saved for frame_292.png
# Histogram saved for frame_293.png
# Histogram saved for frame_294.png
# Histogram saved for frame_295.png
# Histogram saved for frame_296.png
# Histogram saved for frame_297.png
# Histogram saved for frame_298.png
# Histogram saved for frame_299.png
# Histogram saved for frame_300.png
# Histogram saved for frame_301.png
# Histogram saved for frame_302.png
# Histogram saved for frame_303.png
# Histogram saved for frame_304.png
# Histogram saved for frame_305.png
# Histogram saved for frame_306.png
# Histogram saved for frame_307.png
# Histogram saved for frame_308.png
# Histogram saved for frame_309.png
# Histogram saved for frame_310.png
# Histogram saved for frame_311.png
# Histogram saved for frame_312.png
# Histogram saved for frame_313.png
# Histogram saved for frame_314.png
# Histogram saved for frame_315.png
# Histogram saved for frame_316.png
# Histogram saved for frame_317.png
# Histogram saved for frame_318.png
# Histogram saved for frame_319.png
# Histogram saved for frame_320.png
# Histogram saved for frame_321.png
# Histogram saved for frame_322.png
# Histogram saved for frame_323.png
# Histogram saved for frame_324.png
# Histogram saved for frame_325.png
# Histogram saved for frame_326.png
# Histogram saved for frame_327.png
# Histogram saved for frame_328.png
# Histogram saved for frame_329.png
# Histogram saved for frame_330.png
# Histogram saved for frame_331.png
# Histogram saved for frame_332.png
# Histogram saved for frame_333.png
# Histogram saved for frame_334.png
# Histogram saved for frame_335.png
# Histogram saved for frame_336.png
# Histogram saved for frame_337.png
# Histogram saved for frame_338.png
# Histogram saved for frame_339.png
# Histogram saved for frame_340.png
# Histogram saved for frame_341.png
# Histogram saved for frame_342.png
# Histogram saved for frame_343.png
# Histogram saved for frame_344.png
# Histogram saved for frame_345.png
# Histogram saved for frame_346.png
# Histogram saved for frame_347.png
# Histogram saved for frame_348.png
# Histogram saved for frame_349.png
# Histogram saved for frame_350.png
# Histogram saved for frame_351.png
# Histogram saved for frame_352.png
# Histogram saved for frame_353.png
# Histogram saved for frame_354.png
# Histogram saved for frame_355.png
# Histogram saved for frame_356.png
# Histogram saved for frame_357.png
# Histogram saved for frame_358.png
# Histogram saved for frame_359.png
# Histogram saved for frame_360.png
# Histogram saved for frame_361.png
# Histogram saved for frame_362.png
# Histogram saved for frame_363.png
# Histogram saved for frame_364.png
# Histogram saved for frame_365.png
# Histogram saved for frame_366.png
# Histogram saved for frame_367.png
# Histogram saved for frame_368.png
# Histogram saved for frame_369.png
# Histogram saved for frame_370.png
# Histogram saved for frame_371.png
# Histogram saved for frame_372.png
# Histogram saved for frame_373.png
# Histogram saved for frame_374.png
# Histogram saved for frame_375.png
# Histogram saved for frame_376.png
# Histogram saved for frame_377.png
# Histogram saved for frame_378.png
# Histogram saved for frame_379.png
# Histogram saved for frame_380.png
# Histogram saved for frame_381.png
# Histogram saved for frame_382.png
# Histogram saved for frame_383.png
# Histogram saved for frame_384.png
# Histogram saved for frame_385.png
# Histogram saved for frame_386.png
# Histogram saved for frame_387.png
# Histogram saved for frame_388.png
# Histogram saved for frame_389.png
# Histogram saved for frame_390.png
# Histogram saved for frame_391.png
# Histogram saved for frame_392.png
# Histogram saved for frame_393.png
# Histogram saved for frame_394.png
# Histogram saved for frame_395.png
# Histogram saved for frame_396.png
# Histogram saved for frame_397.png
# Histogram saved for frame_398.png
# Histogram saved for frame_399.png
# Histogram saved for frame_400.png
# Histogram saved for frame_401.png
# Histogram saved for frame_402.png
# Histogram saved for frame_403.png
# Histogram saved for frame_404.png
# Histogram saved for frame_405.png
# Histogram saved for frame_406.png
# Histogram saved for frame_407.png
# Histogram saved for frame_408.png
# Histogram saved for frame_409.png
# Histogram saved for frame_410.png
# Histogram saved for frame_411.png
# Histogram saved for frame_412.png
# Histogram saved for frame_413.png
# Histogram saved for frame_414.png
# Histogram saved for frame_415.png
# Histogram saved for frame_416.png
# Histogram saved for frame_417.png
# Histogram saved for frame_418.png
# Histogram saved for frame_419.png
# Histogram saved for frame_420.png
# Histogram saved for frame_421.png
# Histogram saved for frame_422.png
# Histogram saved for frame_423.png
# Histogram saved for frame_424.png
# Histogram saved for frame_425.png
# Histogram saved for frame_426.png
# Histogram saved for frame_427.png
# Histogram saved for frame_428.png
# Histogram saved for frame_429.png
# Histogram saved for frame_430.png
# Histogram saved for frame_431.png
# Histogram saved for frame_432.png
# Histogram saved for frame_433.png
# Histogram saved for frame_434.png
# Histogram saved for frame_435.png
# Histogram saved for frame_436.png
# Histogram saved for frame_437.png
# Histogram saved for frame_438.png
# Histogram saved for frame_439.png
# Histogram saved for frame_440.png
# Histogram saved for frame_441.png
# Histogram saved for frame_442.png
# Histogram saved for frame_443.png
# Histogram saved for frame_444.png
# Histogram saved for frame_445.png
# Histogram saved for frame_446.png
# Histogram saved for frame_447.png
# Histogram saved for frame_448.png
# Histogram saved for frame_449.png
# Histogram saved for frame_450.png
# Histogram saved for frame_451.png
# Histogram saved for frame_452.png
# Histogram saved for frame_453.png
# Histogram saved for frame_454.png
# Histogram saved for frame_455.png
# Histogram saved for frame_456.png
# Histogram saved for frame_457.png
# Histogram saved for frame_458.png
# Histogram saved for frame_459.png
# Histogram saved for frame_460.png
# Histogram saved for frame_461.png
# Histogram saved for frame_462.png
# Histogram saved for frame_463.png
# Histogram saved for frame_464.png
# Histogram saved for frame_465.png
# Histogram saved for frame_466.png
# Histogram saved for frame_467.png
# Histogram saved for frame_468.png
# Histogram saved for frame_469.png
# Histogram saved for frame_470.png
# Histogram saved for frame_471.png
# Histogram saved for frame_472.png
# Histogram saved for frame_473.png
# Histogram saved for frame_474.png
# Histogram saved for frame_475.png
# Histogram saved for frame_476.png
# Histogram saved for frame_477.png
# Histogram saved for frame_478.png
# Histogram saved for frame_479.png
# Histogram saved for frame_480.png
# Histogram saved for frame_481.png
# Histogram saved for frame_482.png
# Histogram saved for frame_483.png
# Histogram saved for frame_484.png
# Histogram saved for frame_485.png
# Histogram saved for frame_486.png
# Histogram saved for frame_487.png
# Histogram saved for frame_488.png
# Histogram saved for frame_489.png
# Histogram saved for frame_490.png
# Histogram saved for frame_491.png
# Histogram saved for frame_492.png
# Histogram saved for frame_493.png
# Histogram saved for frame_494.png
# Histogram saved for frame_495.png
# Histogram saved for frame_496.png
# Histogram saved for frame_497.png
# Histogram saved for frame_498.png
# Histogram saved for frame_499.png
# Histogram saved for frame_500.png
# Histogram saved for frame_501.png
# Histogram saved for frame_502.png
# Histogram saved for frame_503.png
# Histogram saved for frame_504.png
# Histogram saved for frame_505.png
# Histogram saved for frame_506.png
# Histogram saved for frame_507.png
# Histogram saved for frame_508.png
# Histogram saved for frame_509.png
# Histogram saved for frame_510.png
# Histogram saved for frame_511.png
# Histogram saved for frame_512.png
# Histogram saved for frame_513.png
# Histogram saved for frame_514.png
# Histogram saved for frame_515.png
# Histogram saved for frame_516.png
# Histogram saved for frame_517.png
# Histogram saved for frame_518.png
# Histogram saved for frame_519.png
# Histogram saved for frame_520.png
# Histogram saved for frame_521.png
# Histogram saved for frame_522.png
# Histogram saved for frame_523.png
# Histogram saved for frame_524.png
# Histogram saved for frame_525.png
# Histogram saved for frame_526.png
# Histogram saved for frame_527.png
# Histogram saved for frame_528.png
# Histogram saved for frame_529.png
# Histogram saved for frame_530.png
# Histogram saved for frame_531.png
# Histogram saved for frame_532.png
# Histogram saved for frame_533.png
# Histogram saved for frame_534.png
# Histogram saved for frame_535.png
# Histogram saved for frame_536.png
# Histogram saved for frame_537.png
# Histogram saved for frame_538.png
# Histogram saved for frame_539.png
# Histogram saved for frame_540.png
# Histogram saved for frame_541.png
# Histogram saved for frame_542.png
# Histogram saved for frame_543.png
# Histogram saved for frame_544.png
# Histogram saved for frame_545.png
# Histogram saved for frame_546.png
# Histogram saved for frame_547.png
# Histogram saved for frame_548.png
# Histogram saved for frame_549.png
# Histogram saved for frame_550.png
# Histogram saved for frame_551.png
# Histogram saved for frame_552.png
# Histogram saved for frame_553.png
# Histogram saved for frame_554.png
# Histogram saved for frame_555.png
# Histogram saved for frame_556.png
# Histogram saved for frame_557.png
# Histogram saved for frame_558.png
# Histogram saved for frame_559.png
# Histogram saved for frame_560.png
# Histogram saved for frame_561.png
# Histogram saved for frame_562.png
# Histogram saved for frame_563.png
# Histogram saved for frame_564.png
# Histogram saved for frame_565.png
# Histogram saved for frame_566.png
# Histogram saved for frame_567.png
# Histogram saved for frame_568.png
# Histogram saved for frame_569.png
# Histogram saved for frame_570.png
# Histogram saved for frame_571.png
# Histogram saved for frame_572.png
# Histogram saved for frame_573.png
# Histogram saved for frame_574.png
# Histogram saved for frame_575.png
# Histogram saved for frame_576.png
# Histogram saved for frame_577.png
# Histogram saved for frame_578.png
# Histogram saved for frame_579.png
# Histogram saved for frame_580.png
# Histogram saved for frame_581.png
# Histogram saved for frame_582.png
# Histogram saved for frame_583.png
# Histogram saved for frame_584.png
# Histogram saved for frame_585.png
# Histogram saved for frame_586.png
# Histogram saved for frame_587.png
# Histogram saved for frame_588.png
# Histogram saved for frame_589.png
# Histogram saved for frame_590.png
# Histogram saved for frame_591.png
# Histogram saved for frame_592.png
# Histogram saved for frame_593.png
# Histogram saved for frame_594.png
# Histogram saved for frame_595.png
# Histogram saved for frame_596.png
# Histogram saved for frame_597.png
# Histogram saved for frame_598.png
# Histogram saved for frame_599.png
# Histogram saved for frame_600.png
# Histogram saved for frame_601.png
# Histogram saved for frame_602.png
# Histogram saved for frame_603.png
# Histogram saved for frame_604.png
# Histogram saved for frame_605.png
# Histogram saved for frame_606.png
# Histogram saved for frame_607.png
# Histogram saved for frame_608.png
# Histogram saved for frame_609.png
# Histogram saved for frame_610.png
# Histogram saved for frame_611.png
# Histogram saved for frame_612.png
# Histogram saved for frame_613.png
# Histogram saved for frame_614.png
# Histogram saved for frame_615.png
# Histogram saved for frame_616.png
# Histogram saved for frame_617.png
# Histogram saved for frame_618.png
# Histogram saved for frame_619.png
# Histogram saved for frame_620.png
# Histogram saved for frame_621.png
# Histogram saved for frame_622.png
# Histogram saved for frame_623.png
# Histogram saved for frame_624.png
# Histogram saved for frame_625.png
# Histogram saved for frame_626.png
# Histogram saved for frame_627.png
